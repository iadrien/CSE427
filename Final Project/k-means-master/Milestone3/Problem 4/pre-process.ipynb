# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
Accidents = pd.read_csv('./dft-accident-data/Accidents0515.csv', sep=',')
Accidents = Accidents.filter(items=['Longitude', 'Latitude'])

# %%
fig, ax = plt.subplots()
ax.scatter(Accidents.Longitude, Accidents.Latitude, marker="o",alpha=0.3)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize=10)
ax.set_title('accident data')
ax.grid(True)
fig.tight_layout()

plt.show()

# %%
Accidents.to_csv('./dft-accident-data/Accidents.txt', header=False, encoding='utf8')

# %%
rows = np.random.choice(Accidents.index.values, 1000)
sampled_df = Accidents.iloc [rows]

# %%
fig, ax = plt.subplots()
ax.scatter(sampled_df.Longitude, sampled_df.Latitude, marker="o",alpha=0.3)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize=10)
ax.set_title('accident data')
ax.grid(True)
fig.tight_layout()

plt.show()

# %%
sampled_df.to_csv('./dft-accident-data/Accidents-sample.txt', header=False, encoding='utf8')

# %%
from pyspark import SparkContext
sc = SparkContext()

# %%
accidents = sc.textFile("./dft-accident-data/Accidents.txt")\
    .map(lambda line: line.split(','))\
    .filter(lambda tokens: any(tokens[1]) and any(tokens[2]))\
    .map(lambda tokens: (tokens[1], tokens[2]))\
    .map(lambda tokens: ((float(tokens[0])), float(tokens[1]))).cache()

# %%
accidents.take(3)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-18-91992c0bcc75> in <module>()
# ----> 1 accidents.take(3)
#
# ~\Anaconda3\lib\site-packages\pyspark\rdd.py in take(self, num)
#    1358
#    1359             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1360             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1361
#    1362             items += res
#
# ~\Anaconda3\lib\site-packages\pyspark\context.py in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#    1049         # SparkContext#runJob.
#    1050         mappedRDD = rdd.mapPartitions(partitionFunc)
# -> 1051         sock_info = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, partitions)
#    1052         return list(_load_from_socket(sock_info, mappedRDD._jrdd_deserializer))
#    1053
#
# ...
